# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/HSall_members.csv")

# %%
df.head()
# Out:
#    congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0         1  President  99869           99            0.0          USA
# 1         1      House    379           44            2.0           GA
# 2         1      House   4854           44            1.0           GA
# 3         1      House   6071           44            3.0           GA
# 4         1      House   1538           52            6.0           MD
#
#    party_code  occupancy  last_means             bioname bioguide_id    born  \
# 0        5000        NaN         NaN  WASHINGTON, George         NaN     NaN
# 1        4000        0.0         1.0    BALDWIN, Abraham     B000084  1754.0
# 2        4000        0.0         1.0      JACKSON, James     J000017  1757.0
# 3        4000        0.0         1.0     MATHEWS, George     M000234  1739.0
# 4        5000        0.0         1.0     CARROLL, Daniel     C000187  1730.0
#
#      died  nominate_dim1  nominate_dim2  nominate_log_likelihood  \
# ...
